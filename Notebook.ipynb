# %%
import driver.py as pd
# Out:
# *************Tree before pruning*******
# Is PetalW >= 1.0?      Depth :  0      Id :  0
# --> True:
#   Is PetalW >= 1.8?      Depth :  1      Id :  2
#   --> True:
#     Is PetalL >= 4.9?      Depth :  2      Id :  6
#     --> True:
#       Predict {'Iris-virginica': 35}
#       Predicted Class label  Iris-virginica      Depth :  3      Id :  14
#     --> False:
#       Is SepalW >= 3.2?      Depth :  3      Id :  13
#       --> True:
#         Predict {'Iris-versicolor': 1}
#         Predicted Class label  Iris-versicolor      Depth :  4      Id :  28
#       --> False:
#         Predict {'Iris-virginica': 2}
#         Predicted Class label  Iris-virginica      Depth :  4      Id :  27
#   --> False:
#     Is PetalL >= 5.1?      Depth :  2      Id :  5
#     --> True:
#       Predict {'Iris-virginica': 2}
#       Predicted Class label  Iris-virginica      Depth :  3      Id :  12
#     --> False:
#       Is SepalL >= 5.0?      Depth :  3      Id :  11
#       --> True:
# ...

# %%
import driver.py as pd
# Out:
# *************Tree before pruning*******
# Is persons == 2?      Depth :  0      Id :  0
# --> True:
#   Predict {'unacc': 469}
#   Predicted Class label  unacc      Depth :  1      Id :  2
# --> False:
#   Is safety == low?      Depth :  1      Id :  1
#   --> True:
#     Predict {'unacc': 305}
#     Predicted Class label  unacc      Depth :  2      Id :  4
#   --> False:
#     Is maint == vhigh?      Depth :  2      Id :  3
#     --> True:
#       Is buying == vhigh?      Depth :  3      Id :  8
#       --> True:
#         Predict {'unacc': 37}
#         Predicted Class label  unacc      Depth :  4      Id :  18
#       --> False:
#         Is buying == high?      Depth :  4      Id :  17
#         --> True:
#           Predict {'unacc': 37}
#           Predicted Class label  unacc      Depth :  5      Id :  36
#         --> False:
#           Is lug_boot == small?      Depth :  5      Id :  35
#           --> True:
#             Is safety == med?      Depth :  6      Id :  72
# ...

# %%
import driver.py as pd
# Out:
# *************Tree before pruning*******
# Is family == TN?      Depth :  0      Id :  0
# --> True:
#   Predict {'5': 56}
#   Predicted Class label  5      Depth :  1      Id :  2
# --> False:
#   Is surface-quality == ??      Depth :  1      Id :  1
#   --> True:
#     Is carbon >= 6?      Depth :  2      Id :  4
#     --> True:
#       Predict {'3': 45}
#       Predicted Class label  3      Depth :  3      Id :  10
#     --> False:
#       Is condition == S?      Depth :  3      Id :  9
#       --> True:
#         Is thick >= 0.8?      Depth :  4      Id :  20
#         --> True:
#           Is enamelability == 1?      Depth :  5      Id :  42
#           --> True:
#             Predict {'3': 1}
#             Predicted Class label  3      Depth :  6      Id :  86
#           --> False:
#             Predict {'2': 54}
#             Predicted Class label  2      Depth :  6      Id :  85
#         --> False:
#           Predict {'3': 4}
# ...
